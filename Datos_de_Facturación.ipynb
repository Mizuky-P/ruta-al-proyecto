# %%
#Importamos las librerias necesarias
import pandas as pd

# %%
#Carga desde un archivo .xlsx sin indice
facturacion = pd.read_excel('Datos de Facturación.xlsx')
facturacion.head(5)
# Out:
#   CVE_DOC    CVE_CLPV STATUS  CVE_VEND           FECHAELAB  FECHA_DOC  \
# 0  F29414        2465      C       1.0 2019-09-03 08:58:42 2019-09-03
# 1  F29415        3926      C       1.0 2019-09-03 09:55:14 2019-09-03
# 2  F29416        3926      C       1.0 2019-09-03 13:25:33 2019-09-03
# 3  F29417        3926      C       1.0 2019-09-03 13:33:23 2019-09-03
# 4  F29418        6813      C       2.0 2019-09-03 14:23:45 2019-09-03
#
#              FECHA_ENT  FECHA_VEN FECHA_CANCELA  CAN_TOT  DES_TOT  DES_FIN
# 0  2019-09-03 00:00:00 2019-09-18    2019-09-04  3980.00      0.0      0.0
# 1  2019-09-03 00:00:00 2019-10-03    2019-09-03  1550.00      0.0      0.0
# 2  2019-09-03 00:00:00 2019-10-03    2019-09-03  1550.00      0.0      0.0
# 3  2019-09-03 00:00:00 2019-10-03    2019-09-17  1550.00      0.0      0.0
# 4  2019-09-03 00:00:00 2019-09-03    2019-09-10  2435.44      0.0      0.0

# %%
#Identificar valores nulos por columna
valores_nulos_facturacion=facturacion.isnull().sum()
valores_nulos_facturacion
# Out:
# CVE_DOC              5
# CVE_CLPV             0
# STATUS               9
# CVE_VEND            48
# FECHAELAB            2
# FECHA_DOC            1
# FECHA_ENT            2
# FECHA_VEN            0
# FECHA_CANCELA    10537
# CAN_TOT              6
# DES_TOT              1
# DES_FIN              3
# dtype: int64

# %%
#Realizamos una copia del dataframe
facturacion1 = facturacion.copy()

# %%
#Primer método de sustitución de valores nulos
#Sustitucion por promedio para valores numericos
facturacion1["CVE_VEND"]=facturacion1["CVE_VEND"].fillna(round(facturacion["CVE_VEND"].mean(),1))
facturacion1["CAN_TOT"]=facturacion1["CAN_TOT"].fillna(round(facturacion["CAN_TOT"].mean(),1))
facturacion1["DES_TOT"]=facturacion1["DES_TOT"].fillna(round(facturacion["DES_TOT"].mean(),1))
facturacion1["DES_FIN"]=facturacion1["DES_FIN"].fillna(round(facturacion["DES_FIN"].mean(),1))

# %%
#Identificar valores nulos por columna
valores_nulos_facturacion1=facturacion1.isnull().sum()
valores_nulos_facturacion1
# Out:
# CVE_DOC              5
# CVE_CLPV             0
# STATUS               9
# CVE_VEND             0
# FECHAELAB            2
# FECHA_DOC            1
# FECHA_ENT            2
# FECHA_VEN            0
# FECHA_CANCELA    10537
# CAN_TOT              0
# DES_TOT              0
# DES_FIN              0
# dtype: int64

# %%
#Sexto método de sustitución de valores nulos
#Sustitucion para valores de fecha con el metodo de sustitucion por valores no nulos hacia adelante
facturacion1["FECHAELAB"] =facturacion1["FECHAELAB"].fillna(method="ffill")
facturacion1["FECHA_DOC"] =facturacion1["FECHA_DOC"].fillna(method="ffill")
facturacion1["FECHA_ENT"] =facturacion1["FECHA_ENT"].fillna(method="ffill")
facturacion1["FECHA_CANCELA"] =facturacion1["FECHA_CANCELA"].fillna(method="ffill")
# Out:
# <ipython-input-26-51800f616769>:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   facturacion1["FECHAELAB"] =facturacion1["FECHAELAB"].fillna(method="ffill")
# <ipython-input-26-51800f616769>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   facturacion1["FECHA_DOC"] =facturacion1["FECHA_DOC"].fillna(method="ffill")
# <ipython-input-26-51800f616769>:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   facturacion1["FECHA_ENT"] =facturacion1["FECHA_ENT"].fillna(method="ffill")
# <ipython-input-26-51800f616769>:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   facturacion1["FECHA_CANCELA"] =facturacion1["FECHA_CANCELA"].fillna(method="ffill")

# %%
#Identificar valores nulos por columna
valores_nulos_facturacion1=facturacion1.isnull().sum()
valores_nulos_facturacion1
# Out:
# CVE_DOC          5
# CVE_CLPV         0
# STATUS           9
# CVE_VEND         0
# FECHAELAB        0
# FECHA_DOC        0
# FECHA_ENT        0
# FECHA_VEN        0
# FECHA_CANCELA    0
# CAN_TOT          0
# DES_TOT          0
# DES_FIN          0
# dtype: int64

# %%
#Cuarto método de sustitución de valores nulos
#Sustitucion de otros valores str con el metodo de sustitucion por valores no nulos hacia atras
facturacion1["CVE_DOC"] =facturacion1["CVE_DOC"].fillna(method="bfill")
facturacion1["STATUS"] =facturacion1["STATUS"].fillna(method="bfill")
# Out:
# <ipython-input-31-5755f75fed29>:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   facturacion1["CVE_DOC"] =facturacion1["CVE_DOC"].fillna(method="bfill")
# <ipython-input-31-5755f75fed29>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   facturacion1["STATUS"] =facturacion1["STATUS"].fillna(method="bfill")

# %%
#Identificar valores nulos por columna
valores_nulos_facturacion1=facturacion1.isnull().sum()
valores_nulos_facturacion1
# Out:
# CVE_DOC          0
# CVE_CLPV         0
# STATUS           0
# CVE_VEND         0
# FECHAELAB        0
# FECHA_DOC        0
# FECHA_ENT        0
# FECHA_VEN        0
# FECHA_CANCELA    0
# CAN_TOT          0
# DES_TOT          0
# DES_FIN          0
# dtype: int64

# %%
#Convertir archivo filtrado a CSV
facturacion1.to_csv("Datos de Facturación.csv")

# %%
#Descargar archivo en csv
from google.colab import files
files.download("Datos de Facturación.csv")
